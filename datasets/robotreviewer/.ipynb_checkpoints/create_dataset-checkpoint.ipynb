# %%
import pandas as pd

# %%
text_train_inputs = pd.read_csv('train-inputs.csv')
text_train_targets = pd.read_csv('train-targets.csv')

text_dev_inputs = pd.read_csv('dev-inputs.csv')
text_dev_targets = pd.read_csv('dev-targets.csv')

text_test_inputs = pd.read_csv('test-inputs.csv')
text_test_targets = pd.read_csv('test-targets.csv')

# %%
list(text_dev_targets[text_dev_targets['ReviewID'] == 'CD007016']['Target'])
# Out:
# ['At present, there is insufficient RCT evidence to enable evaluation of the effect of TPD in patients with AKI. Well-designed and larger RCTs are required to better understand the risks and benefits of TPD for AKI.']

# %%
import json

def read_json(filename):
    with open(filename, 'r') as fp:
        all_lines = json.load(fp)
    return all_lines

rr_train_input = read_json('RR-train.json')
rr_train_output = read_json('abstracts-summarization-train.json')
rr_dev_input = read_json('RR-dev.json')
rr_dev_output = read_json('abstracts-summarization-dev.json')
rr_test_input = read_json('RR-test.json')
rr_test_output = read_json('abstracts-summarization-test.json')

# %%
def _make_review_pmid_map(input_data):
    review_pmid_map = {}
    print(input_data.keys())
    for k , rid in input_data['ReviewID'].items():
        pmids = input_data['PMID'][k]
        review_pmid_map[rid] = pmids
    return review_pmid_map

# %%
rr_train_review_pmid_map = _make_review_pmid_map(rr_train_output)
rr_dev_review_pmid_map = _make_review_pmid_map(rr_dev_output)
rr_test_review_pmid_map = _make_review_pmid_map(rr_test_output)
# Out:
# dict_keys(['ReviewID', 'SummaryBackground', 'SummaryConclusions', 'PMID', 'Title', 'Abstract'])
# dict_keys(['ReviewID', 'SummaryBackground', 'SummaryConclusions', 'PMID', 'Title', 'Abstract'])
# dict_keys(['ReviewID', 'SummaryBackground', 'SummaryConclusions', 'PMID', 'Title', 'Abstract'])

# %%
import re, string

def _find_pmid(abstracts, ptext):
    for i,abst in enumerate(abstracts):
            if ptext in abst:
                return i
    return None
  
def preprocess_str(text):
    import re
    puncts = '!"#$%&\'()*+,-/:;<=>?@[\\]^_`{|}~↑↓―'
    regex = re.compile('[%s]' % re.escape(string.punctuation))
    text = regex.sub(' ', text)
    text = [w.lower().strip(puncts) for w in text.split()if w.strip()]
    
    return ' '.join(text)

def preprocess(row_vals):
    new_row_vals = []
    for each_val in row_vals:
        each_val = each_val if type(each_val) is list else [str(each_val)]
        #print(each_val)
        each_val = [preprocess_str(each) for each in each_val]
        each_val = ' <sep> '.join(each_val)
        new_row_vals.append(each_val)
    return new_row_vals

def make_review_data(review_pmid_map, text_inputs, rr_input, text_target):
    review_data = {'PMID' : [], 'Abstract' : [], 'ReviewID': [], 'SummaryConclusions': []}
    for rid, pmids in review_pmid_map.items():
        pmids = [int(each) for each in pmids]
        df_sample = text_inputs[text_inputs['PMID'].isin(pmids)]
        df_sample = df_sample[df_sample['Abstract'].notna()]
        df_pmids = list(df_sample['PMID'])
        df_abstract = list(df_sample['Abstract'])
        target = text_target[text_target['ReviewID'] == rid]
        target = list(target['Target'])[0]
        target = preprocess_str(target)
        pmid_data = []
        abstract_data = []
        pico_data = {}
        for pico_ele in rr_input[rid]:
            punchline_text = pico_ele['punchline_text']
            pmid_ind = _find_pmid(df_abstract, punchline_text)
            if pmid_ind:
                pmid = df_pmids[pmid_ind]
                abstract = df_abstract[pmid_ind]
                pmid_data.append(pmid)
                abstract_data.append(abstract)
                
                for k , v in pico_ele.items():
                    if k not in pico_data:
                        pico_data[k] = []
                    pico_data[k].append(v)
        if pmid_data:
            if not df_abstract:
                print(rid)
            pmid_data = preprocess(pmid_data)
            abstract_data = preprocess(abstract_data)
            
            #review_data['PMID'].append(pmid_data)
            #review_data['Abstract'].append(abstract_data)
            for k , v in pico_data.items():
                if 'mesh' not in k:
                    v = preprocess(v)
                    pico_data[k] = v
                    if k not in review_data:
                        review_data[k] = []
                    #v = ["<%s> "%k + each + " </%s>"%k for each in v]
                    #v = " ".join(v)
                    review_data[k].append(v)
            review_data['PMID'].append(pmid_data)
            review_data['Abstract'].append(abstract_data)
            review_data['ReviewID'].append(rid)
            review_data['SummaryConclusions'].append(target)
                
    return review_data

# %%
review_data_dev = make_review_data(rr_dev_review_pmid_map, text_dev_inputs, rr_dev_input, text_dev_targets)

# %%
review_data_dev['ReviewID']
# Out:
# ['CD007119',
#  'CD006525',
#  'CD005571',
#  'CD003390',
#  'CD002830',
#  'CD003656',
#  'CD004450',
#  'CD006919',
#  'CD005653',
#  'CD002170',
#  'CD008686',
#  'CD006182',
#  'CD007921',
#  'CD004439',
#  'CD007775',
#  'CD005515',
#  'CD003317',
#  'CD008407',
#  'CD005454',
#  'CD001951',
#  'CD002744',
#  'CD004374',
#  'CD004954',
#  'CD005550',
#  'CD006001',
#  'CD005640',
#  'CD006188',
#  'CD000328',
#  'CD008896',
#  'CD003046',
#  'CD003078',
#  'CD005170',
#  'CD001281',
#  'CD001545',
#  'CD005291',
#  'CD006921',
#  'CD008914',
#  'CD006063',
#  'CD001531',
#  'CD009107',
#  'CD003669',
#  'CD003150',
#  'CD000165',
#  'CD007176',
#  'CD007990',
#  'CD000212',
#  'CD003895',
#  'CD010609',
#  'CD002759',
#  'CD004147',
#  'CD004402',
#  'CD007004',
#  'CD000088',
#  'CD000019',
#  'CD009411',
#  'CD003092',
#  'CD007440',
#  'CD007302',
#  'CD005533',
#  'CD004621',
#  'CD003487',
#  'CD009046',
#  'CD003076',
#  'CD001708',
#  'CD003822',
#  'CD003388',
#  'CD003265',
#  'CD003283',
#  'CD007749',
#  'CD006225',
#  'CD007196',
#  'CD008444',
#  'CD004441',
#  'CD006971',
#  'CD004316',
#  'CD000424',
#  'CD008392',
#  'CD003132',
#  'CD001717',
#  'CD002011',
#  'CD006213',
#  'CD004614',
#  'CD006459',
#  'CD006331',
#  'CD009337',
#  'CD001108',
#  'CD007649',
#  'CD001035',
#  'CD008148',
#  'CD001829',
#  'CD009510',
#  'CD006244',
#  'CD002943',
#  'CD004464',
#  'CD005123',
#  'CD004323',
#  'CD009779',
#  'CD000332',
#  'CD000201',
#  'CD004228',
#  'CD004764',
#  'CD007539',
#  'CD005030',
#  'CD004001',
#  'CD000301',
#  'CD009401',
#  'CD006429',
#  'CD000527',
#  'CD008250',
#  'CD003808',
#  'CD007360',
#  'CD002192',
#  'CD005326',
#  'CD001242',
#  'CD006613',
#  'CD003989',
#  'CD000164',
#  'CD001950',
#  'CD009882',
#  'CD003277',
#  'CD008987',
#  'CD002969',
#  'CD004389',
#  'CD005556',
#  'CD007859',
#  'CD005417',
#  'CD002863',
#  'CD000954',
#  'CD003833',
#  'CD004386',
#  'CD005064',
#  'CD000126',
#  'CD006884',
#  'CD007592',
#  'CD003236',
#  'CD002279',
#  'CD008228',
#  'CD005179',
#  'CD000968',
#  'CD007079',
#  'CD009662',
#  'CD001247',
#  'CD001546',
#  'CD000093',
#  'CD004665',
#  'CD004796',
#  'CD009189',
#  'CD001903',
#  'CD008562',
#  'CD000407',
#  'CD008691',
#  'CD006591',
#  'CD004249',
#  'CD005232',
#  'CD005380',
#  'CD006254',
#  'CD003933',
#  'CD008445',
#  'CD007202',
#  'CD006105',
#  'CD006034',
#  'CD005482',
#  'CD007857',
#  'CD005060',
#  'CD003797',
#  'CD002928',
#  'CD001724',
#  'CD004458',
#  'CD006857',
#  'CD009209',
#  'CD003710',
#  'CD002261',
#  'CD003745',
#  'CD004029',
#  'CD010424',
#  'CD001177',
#  'CD001088',
#  'CD003993',
#  'CD001054',
#  'CD007675',
#  'CD006247',
#  'CD001211',
#  'CD003048',
#  'CD003064',
#  'CD007851',
#  'CD001466',
#  'CD008386',
#  'CD008037',
#  'CD006643',
#  'CD004306',
#  'CD005103',
#  'CD007624',
#  'CD002900',
#  'CD008312',
#  'CD007295',
#  'CD006559',
#  'CD003918',
#  'CD009414',
#  'CD000361',
#  'CD001190',
#  'CD004567',
#  'CD004026',
#  'CD004334',
#  'CD001021',
#  'CD003476',
#  'CD001230',
#  'CD004886',
#  'CD000387',
#  'CD002829',
#  'CD002771',
#  'CD001125',
#  'CD004898',
#  'CD003676',
#  'CD003840',
#  'CD004631',
#  'CD006014',
#  'CD006154',
#  'CD000412',
#  'CD001552',
#  'CD008538',
#  'CD002751',
#  'CD006900',
#  'CD006801',
#  'CD004907',
#  'CD003254',
#  'CD008408',
#  'CD003719',
#  'CD007235',
#  'CD004916',
#  'CD004530',
#  'CD000313',
#  'CD006581',
#  'CD006179',
#  'CD007271',
#  'CD004047',
#  'CD003204',
#  'CD007584',
#  'CD002248',
#  'CD003873',
#  'CD007632',
#  'CD002256',
#  'CD000052',
#  'CD003816',
#  'CD005040',
#  'CD003303',
#  'CD001746',
#  'CD001914',
#  'CD003901',
#  'CD001181',
#  'CD005565',
#  'CD005272',
#  'CD008600',
#  'CD008366',
#  'CD001216',
#  'CD003615',
#  'CD003401',
#  'CD007444',
#  'CD006073',
#  'CD002778',
#  'CD008237',
#  'CD004408',
#  'CD001333',
#  'CD004070',
#  'CD004885',
#  'CD006140',
#  'CD002038',
#  'CD003296',
#  'CD007388',
#  'CD003135',
#  'CD003175',
#  'CD006569',
#  'CD004180',
#  'CD002232',
#  'CD004304',
#  'CD004009',
#  'CD006955',
#  'CD007635',
#  'CD007303',
#  'CD001327',
#  'CD000391',
#  'CD007815',
#  'CD004348',
#  'CD004794',
#  'CD004522',
#  'CD001777',
#  'CD004416',
#  'CD003439',
#  'CD001867',
#  'CD005393',
#  'CD004251',
#  'CD001972',
#  'CD007830',
#  'CD001401',
#  'CD004854',
#  'CD004139',
#  'CD003546',
#  'CD003318',
#  'CD000020',
#  'CD002787',
#  'CD001877',
#  'CD003153',
#  'CD005576',
#  'CD006483',
#  'CD007287',
#  'CD008016',
#  'CD003452',
#  'CD005968',
#  'CD001366',
#  'CD009131',
#  'CD003683',
#  'CD000498',
#  'CD006780',
#  'CD004329',
#  'CD007667',
#  'CD007960',
#  'CD007253',
#  'CD004574',
#  'CD001321',
#  'CD004296',
#  'CD004959',
#  'CD001871',
#  'CD004040',
#  'CD004808',
#  'CD001704',
#  'CD001496',
#  'CD009607',
#  'CD004544',
#  'CD006579',
#  'CD003248',
#  'CD004437',
#  'CD003161',
#  'CD008084',
#  'CD008320',
#  'CD004064',
#  'CD003432',
#  'CD000277',
#  'CD007842',
#  'CD005963',
#  'CD007557',
#  'CD004976',
#  'CD003320',
#  'CD005112',
#  'CD001706',
#  'CD004236',
#  'CD001863',
#  'CD004762',
#  'CD008054',
#  'CD004655',
#  'CD001257',
#  'CD004851',
#  'CD004315',
#  'CD004379',
#  'CD005287',
#  'CD004680',
#  'CD006687',
#  'CD001728',
#  'CD007629',
#  'CD008007',
#  'CD005168',
#  'CD000148',
#  'CD004423',
#  'CD006269',
#  'CD003315',
#  'CD007679',
#  'CD006893',
#  'CD010119',
#  'CD002923',
#  'CD001263',
#  'CD006089',
#  'CD007570',
#  'CD002238',
#  'CD005555',
#  'CD001929',
#  'CD006201',
#  'CD000503',
#  'CD008739',
#  'CD008326',
#  'CD002140',
#  'CD006860',
#  'CD003289',
#  'CD001888',
#  'CD008635',
#  'CD006075',
#  'CD004588',
#  'CD008933',
#  'CD005451',
#  'CD000459',
#  'CD000025',
#  'CD005495',
#  'CD004168',
#  'CD004602',
#  'CD007031',
#  'CD007954',
#  'CD005187',
#  'CD002119',
#  'CD007583',
#  'CD004635',
#  'CD001843',
#  'CD007877',
#  'CD004597',
#  'CD004833',
#  'CD006120',
#  'CD005511',
#  'CD004380',
#  'CD008152',
#  'CD004012',
#  'CD009217',
#  'CD002929',
#  'CD006103',
#  'CD004079',
#  'CD006576',
#  'CD007145']

# %%
dev_df = pd.DataFrame(review_data_dev)

# %%
def _sanity_check(df):
    for ind, row in df.iterrows():
        pmids = list(row['PMID'])
        pop = list(row['population'])
        Abstract = list(row['Abstract'])
        
        assert( len(pmids) == len(pop) ==len(Abstract))

# %%
_sanity_check(dev_df)

# %%
dev_df
# Out:
#                                                   PMID  \
# 0     [15178717, 11487675, 7878629, 15351854, 9215844]
# 1    [18802161, 10634337, 8857869, 17504586, 163306...
# 2    [12869081, 17099376, 10768245, 16167973, 75559...
# 3                                   [1974941, 8257478]
# 4                                            [6376480]
# ..                                                 ...
# 407                                [20575920, 1853618]
# 408  [20409497, 16908789, 21041839, 21991893, 21635...
# 409  [10874062, 12621132, 12621133, 7698575, 119324...
# 410  [9598622, 19135641, 7269016, 17552953, 6895918...
# 411  [17023707, 12008645, 19775782, 21466516, 21354...
#
#                                               Abstract  ReviewID  \
# 0    [recombinant urokinase r uk is a high molecula...  CD007119
# 1    [to determine the effectiveness of the allevia...  CD006525
# 2    [peristomal infection can sometimes complicate...  CD005571
# 3    [41 33 of 123 patients with acute psychiatric ...  CD003390
# 4    [in a double blind clinical study 27 acutely a...  CD002830
# ..                                                 ...       ...
# 407  [ambiguity remains about the effectiveness of ...  CD002929
# 408  [smoking remains the primary preventable cause...  CD006103
# 409  [patients with familial adenomatous polyposis ...  CD004079
# 410  [to compare in a randomized prospective study ...  CD006576
# 411  [pregnancy is a condition in which the glycemi...  CD007145
#
#                                     SummaryConclusions  \
# 0    there is inadequate evidence to draw strong co...
# 1    collaborative care is associated with signific...
# 2    administration of systemic prophylactic antibi...
# 3    the limited available evidence suggests folate...
# 4    this is an important and surprisingly under re...
# ..                                                 ...
# 407  from the limited results it is unclear whether...
# 408  cytisine increases the chances of quitting alt...
# 409  there was evidence from three pooled rcts that...
# 410  antibiotic prophylaxis is effective in prevent...
# 411  there is not enough evidence to recommend any ...
#
#                                            sample_size  \
# 0                       [108, 149, not found, 180, 42]
# 1    [472, not found, 153, 105, 1500, 288, 61, 208,...
# 2    [141, 96, 216, 99, 100, 633, 115, not found, 3...
# 3                                            [123, 96]
# 4                                                 [27]
# ..                                                 ...
# 407                                        [827, 3088]
# 408  [1202, 130, 602, 1542, 198, 128, 618, 32, 714,...
# 409                   [77, 635, 1121, 22, 41, 10, 272]
# 410  [83, not found, 40, 497, 63, 192, 400, 117, 11...
# 411  [5, 80000, 189, not found, 80, 100, not found,...
#
#                                             population  \
# 0    [adult and pediatric patients from 1 year of a...
# 1    [or 18 years with major depression 49 dysthymi...
# 2    [forty patients who for various reasons were a...
# 3    [123 patients with acute psychiatric disorders...
# 4    [27 acutely agitated patients <sep> acutely ag...
# ..                                                 ...
# 407  [eight hundred twenty seven participants under...
# 408  [smokers using varenicline <sep> 2010 american...
# 409  [patients with familial adenomatous polyposis ...
# 410  [patients with symptomatic urinary tract infec...
# 411  [70 women who met the inclusion criteria 62 co...
#
#                                          interventions  \
# 0    [recombinant urokinase urokinase alfa <sep> re...
# 1    [euc <sep> collaborative care management <sep>...
# 2    [percutaneous endoscopic gastrostomy peg place...
# 3    [placebo, oral 5 methyltetrahydrofolic acid <s...
# 4    [haloperidol <sep> intramuscular injection of ...
# ..                                                 ...
# 407  [mask group all non scrubbed staff wore a mask...
# 408  [behavioral smoking cessation program <sep> va...
# 409  [placebo <sep> celecoxib, placebo <sep> aspiri...
# 410  [oral co amoxiclav <sep> oral co amoxiclav gro...
# 411  [low glycemic index diet <sep> dietary counsel...
#
#                                               outcomes  \
# 0    [restoring total cvad function <sep> safety an...
# 1    [emotional <sep> quality of life and lower pai...
# 2    [peristomal wound infection <sep> erythema and...
# 3    [clinical and social recovery, rey s verbal me...
# 4                                                   []
# ..                                                 ...
# 407  [pre operative stay <sep> surgical site infect...
# 408  [percentage of abstinence <sep> abstinence out...
# 409  [mean number of colorectal polyps <sep> number...
# 410  [rate of positive msus <sep> positive msus <se...
# 411  [higher ponderal index <sep> pregnancy outcome...
#
#                                         punchline_text  \
# 0    [all three concentrations of r uk were signifi...
# 1    [improvement was also found for 5 point decrea...
# 2    [peristomal wound infection was significantly ...
# 3    [among both depressed and schizophrenic patien...
# 4    [at 30 minutes following treatment 81 of the p...
# ..                                                 ...
# 407  [overall 83 10 2 surgical site infections were...
# 408  [the ptc group had a significantly higher perc...
# 409  [the reductions in the group receiving 100 mg ...
# 410  [there was no statistically significant differ...
# 411  [the mean diet gi fell significantly in the lg...
#
#                                       punchline_effect  \
# 0    [ sig increase,  no diff,  sig increase,  no d...
# 1    [ sig increase,  no diff,  sig decrease,  sig ...
# 2    [ sig decrease,  no diff,  no diff,  no diff, ...
# 3                       [ sig increase,  sig increase]
# 4                                      [ sig increase]
# ..                                                 ...
# 407                               [ no diff,  no diff]
# 408  [ sig increase,  sig increase,  sig decrease, ...
# 409  [ sig decrease,  sig increase,  sig increase, ...
# 410  [ no diff,  no diff,  sig increase,  sig incre...
# 411  [ sig decrease,  sig increase,  no diff,  no d...
#
#                             random_sequence_generation  \
# 0    [judgement low, judgement low, judgement high ...
# 1    [judgement low, judgement high unclear, judgem...
# 2    [judgement low, judgement high unclear, judgem...
# 3     [judgement high unclear, judgement high unclear]
# 4                             [judgement high unclear]
# ..                                                 ...
# 407            [judgement low, judgement high unclear]
# 408  [judgement high unclear, judgement high unclea...
# 409  [judgement low, judgement low, judgement low, ...
# 410  [judgement high unclear, judgement high unclea...
# 411  [judgement high unclear, judgement high unclea...
#
#                                 allocation_concealment  \
# 0    [judgement low, judgement low, judgement high ...
# 1    [judgement low, judgement high unclear, judgem...
# 2    [judgement low, judgement high unclear, judgem...
# 3     [judgement high unclear, judgement high unclear]
# 4                             [judgement high unclear]
# ..                                                 ...
# 407            [judgement low, judgement high unclear]
# 408  [judgement high unclear, judgement high unclea...
# 409  [judgement high unclear, judgement low, judgem...
# 410  [judgement high unclear, judgement high unclea...
# 411  [judgement high unclear, judgement high unclea...
#
#                        blinding_participants_personnel
# 0    [judgement low, judgement low, judgement high ...
# 1    [judgement low, judgement high unclear, judgem...
# 2    [judgement low, judgement high unclear, judgem...
# 3     [judgement high unclear, judgement high unclear]
# 4                             [judgement high unclear]
# ..                                                 ...
# 407            [judgement low, judgement high unclear]
# 408  [judgement high unclear, judgement high unclea...
# 409  [judgement low, judgement low, judgement low, ...
# 410  [judgement high unclear, judgement high unclea...
# 411  [judgement high unclear, judgement high unclea...
#
# [412 rows x 13 columns]

# %%
list(dev_df['population'].items())[0]
# Out:
# (0,
#  '<population> adult and pediatric patients from 1 year of age <sep> one hundred eight patients with cvad withdrawal or total occlusion were enrolled and randomized to treatment 104 patients received at least one instillation of study drug and 101 patients completed treatment <sep> occluded central venous catheters in oncology patients </population> <population> one hundred forty nine patients were randomized 74 received <sep> patients were eligible for inclusion if blood could not be withdrawn from their catheter after a period of normal function of at least 48 hours </population> <population> thrombosed central venous catheters <sep> fifty dysfunctional central venous catheters proven radiographically to be occluded by thrombus </population> <population> 180 patients were enrolled at 43 sites in the united states and canada <sep> adult and pediatric patients with occluded non hemodialysis cvads of any duration or type <sep> most patients were adults although 20 were 18 years of age </population> <population> cancer patients <sep> forty two patients with vad occlusions refractory to </population>')

# %%
import re
puncts = '!"#$%&\'()*+,-/:;<=>?@[\\]^_`{|}~↑↓―'
a = "he0uw!-t"
a = re.sub(r"[!\"#$%&\'()*+,/:;<=>?@[\\]^_`{|}~↑↓-]+", ' ', a)
a
# Out:
# 'This is  fortunately  A 23 Test  string'
